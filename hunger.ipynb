# %% [markdown]
# <a href="https://colab.research.google.com/github/angelica3022/ange/blob/main/hunger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
hunger_path = '/content/drive/MyDrive/Colab Notebooks/datasets/hunger.csv'
hunger = pd.read_csv(hunger_path)

# %%
x =  hunger['Year']
y = hunger['number_undernourished']

# %%
plt.xlabel('Year')
plt.ylabel('Number Undernourished')
plt.title('HUNGER', fontsize=20)
plt.plot(x,y)
